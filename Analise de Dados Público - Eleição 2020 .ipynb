# %% [markdown]
# Analise de dados públicos - Eleição 2020

# %% [markdown]
# Analise de dados do estado de São Paulo

# %%
# Lendo o banco de dados necessário.
filename = 'perfil_eleitor_secao_ATUAL_SP.csv'
df = pd.read_csv(filename, delimiter=';', 
                 encoding='ISO-8859-1',usecols=['DS_FAIXA_ETARIA', 'DS_GENERO'],
                 error_bad_lines=False)

# %%
df.sample(10)
# Out:
#           DS_GENERO                 DS_FAIXA_ETARIA
# 5797396    FEMININO  30 a 34 anos
# 12528870   FEMININO  21 a 24 anos
# 14586711  MASCULINO  50 a 54 anos
# 7008472   MASCULINO  50 a 54 anos
# 16121073   FEMININO  40 a 44 anos
# 11289635   FEMININO  21 a 24 anos
# 10434839   FEMININO  65 a 69 anos
# 1421518    FEMININO  45 a 49 anos
# 15724421   FEMININO  25 a 29 anos
# 11320392   FEMININO  45 a 49 anos

# %%
colors = ['#FF69B4', '#1E90FF', '#FFFF00', '#FFA500']
df.groupby('DS_GENERO').size().sort_values().plot(kind='pie', autopct='%.2f%%', colors=colors , figsize=(8, 6), title='Quantidade de eleitores por gênero no estado de São Paulo - 2020')
# Out:
# <AxesSubplot:title={'center':'Quantidade de eleitores por gênero no estado de São Paulo - 2020'}, ylabel='None'>

# %%
#Faixa etária dos eleitores no estado de São Paulo.
df.groupby('DS_FAIXA_ETARIA').size().plot(kind='barh', color='#2eb82e').set_title('Faixa etária dos eleitores do estado de SP')
# Out:
# Text(0.5, 1.0, 'Faixa etária dos eleitores do estado de SP')

# %%
# Faixa etária dos eleitores do gênero masculino.
df.query('DS_GENERO == "MASCULINO"').groupby('DS_FAIXA_ETARIA').size().sort_values(ascending=False).head(10).plot(kind='bar', color='#248f8f').set_title('Faixa etária dos eleitores do sexo masculino')
# Out:
# Text(0.5, 1.0, 'Faixa etária dos eleitores do sexo masculino')

# %%
# Faixa etária dos eleitores do gênero feminino.
df.query('DS_GENERO == "FEMININO"').groupby('DS_FAIXA_ETARIA').size().sort_values(ascending=False).head(10).plot(kind='bar', color='#FFFF00').set_title('Faixa etária dos eleitores do sexo feminino')
# Out:
# Text(0.5, 1.0, 'Faixa etária dos eleitores do sexo feminino')

# %% [markdown]
# Analise de dads do estado da Bahia

# %%
# Lendo o banco de dados necessário.
filename = 'perfil_eleitor_secao_2020_BA.csv'
df = pd.read_csv(filename, delimiter=';', 
                 encoding='ISO-8859-1',usecols=['DS_FAIXA_ETARIA', 'DS_GENERO'],
                 error_bad_lines=False)

# %%
df.sample(10)
# Out:
#          DS_GENERO                 DS_FAIXA_ETARIA
# 937147   MASCULINO  35 a 39 anos
# 2391055   FEMININO  25 a 29 anos
# 5358446   FEMININO  65 a 69 anos
# 3307642   FEMININO  55 a 59 anos
# 4646886  MASCULINO  45 a 49 anos
# 1247784   FEMININO  55 a 59 anos
# 802441   MASCULINO  85 a 89 anos
# 3645049  MASCULINO  40 a 44 anos
# 2277276   FEMININO  70 a 74 anos
# 2294742   FEMININO  65 a 69 anos

# %%
colors = ['#FF69B4', '#1E90FF', '#FFFF00', '#FFA500']
df.groupby('DS_GENERO').size().sort_values().plot(kind='pie', autopct='%.2f%%', colors=colors , figsize=(8, 6), title='Quantidade de eleitores por gênero no estado da Bahia - 2020')
# Out:
# <AxesSubplot:title={'center':'Quantidade de eleitores por gênero no estado da Bahia - 2020'}, ylabel='None'>

# %%
# Faixa etária dos eleitores do gênero masculino.
df.query('DS_GENERO == "MASCULINO"').groupby('DS_FAIXA_ETARIA').size().sort_values(ascending=False).head(10).plot(kind='bar', color='#FF69B4').set_title('Faixa etária dos eleitores do sexo masculino')
# Out:
# Text(0.5, 1.0, 'Faixa etária dos eleitores do sexo masculino')

# %%
# Faixa etária dos eleitores do gênero feminino.
df.query('DS_GENERO == "FEMININO"').groupby('DS_FAIXA_ETARIA').size().sort_values(ascending=False).head(10).plot(kind='bar', color='#FF0000').set_title('Faixa etária dos eleitores do sexo feminino')
# Out:
# Text(0.5, 1.0, 'Faixa etária dos eleitores do sexo feminino')

# %% [markdown]
# Analise de dados do estado do Rio Grande do Sul

# %%
# Lendo o banco de dados necessário.
filename = 'perfil_eleitor_secao_2020_RS.csv'
df = pd.read_csv(filename, delimiter=';', 
                 encoding='ISO-8859-1',usecols=['DS_FAIXA_ETARIA', 'DS_GENERO'],
                 error_bad_lines=False)

# %%
df.sample(10)
# Out:
#          DS_GENERO                 DS_FAIXA_ETARIA
# 867128   MASCULINO  50 a 54 anos
# 1134967   FEMININO  25 a 29 anos
# 2837959  MASCULINO  65 a 69 anos
# 1860230  MASCULINO  80 a 84 anos
# 1982118  MASCULINO  40 a 44 anos
# 3881292   FEMININO  45 a 49 anos
# 114046    FEMININO  75 a 79 anos
# 1112465  MASCULINO  40 a 44 anos
# 2052248   FEMININO  40 a 44 anos
# 764314   MASCULINO  55 a 59 anos

# %%
colors = ['#FF69B4', '#1E90FF', '#FFFF00', '#FFA500']
df.groupby('DS_GENERO').size().sort_values().plot(kind='pie', autopct='%.2f%%', colors=colors , figsize=(8, 6), title='Quantidade de eleitores por gênero no estado do Rio Grande do Sul - 2020')
# Out:
# <AxesSubplot:title={'center':'Quantidade de eleitores por gênero no estado do Rio Grande do Sul - 2020'}, ylabel='None'>

# %%
# Faixa etária dos eleitores do gênero masculino.
df.query('DS_GENERO == "MASCULINO"').groupby('DS_FAIXA_ETARIA').size().sort_values(ascending=False).head(10).plot(kind='bar', color='#FF69B4').set_title('Faixa etária dos eleitores do sexo masculino')
# Out:
# Text(0.5, 1.0, 'Faixa etária dos eleitores do sexo masculino')

# %%
# Faixa etária dos eleitores do gênero feminino.
df.query('DS_GENERO == "FEMININO"').groupby('DS_FAIXA_ETARIA').size().sort_values(ascending=False).head(10).plot(kind='bar', color='#00FF00').set_title('Faixa etária dos eleitores do sexo feminino')
# Out:
# Text(0.5, 1.0, 'Faixa etária dos eleitores do sexo feminino')
